# %% [markdown]
# TOOLS

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import re
#Pandas and Re are imported in case you would like to visualise the data as a test

# %% [markdown]
# MAKE CSV

# %%
#Here you create a CSV file to store the data that you scrape later.
#You also have the chance to rename the CSV based on what dataset you are scraping.
#It is also possible to change the field names, but it is important to remember that they must be changed throughout the Notebook
with open('Top100Benelux.csv', 'a', encoding= "utf-8") as csvfile:
        fieldnames = ['name', 'country', 'genres', 'lineup_2017', 'lineup_2018', 'lineup_2019', 'other_lineups']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

# %% [markdown]
# ADD URL

# %%
#Here you add the URL that you will be scraping. This cell also creates the page soup.
URL = 'https://www.electronic-festivals.com/festivals/top100-ranking/benelux'

page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# GET TOP100

# %%
#Because of how the website was structured it was difficult to tell the code to visit each link seperately.
#The HTML however named each page using the extension needed for the various pages in the Top100.
#Therefore this cell collects all the extensions and will later on stick them onto the base URL to create the pages we are aiming to visit.
addons = []
for link in soup.find_all('a', attrs= {'href': re.compile("/event")}):
    x = ''
    x = link.get('href')
    addons.append(x)

print(addons)
# Out:
# ['/event/amsterdam-dance-event', '/event/tomorrowland', '/event/tomorrowland-weekend-2', '/event/mysteryland', '/event/defqon1', '/event/awakenings-festival', '/event/intents-festival', '/event/decibel-outdoor-festival', '/event/the-qontinent', '/event/extrema-outdoor-belgium', '/event/emporium-festival', '/event/rebirth-festival', '/event/supersized-kingsday', '/event/amsterdam-open-air', '/event/dgtl-festival', '/event/dominator-the-hardcore-festival', '/event/masters-of-hardcore-nl', '/event/sunrise-festival-belgium', '/event/loveland-festival', '/event/we-are-electric', '/event/dream-village', '/event/freshtival', '/event/so-whappy', '/event/7th-sunday-festival', '/event/airforce-festival', '/event/wish-outdoor-netherlands', '/event/dekmantel-festival', '/event/welcome-to-the-future', '/event/dreamfields', '/event/dourfestival', '/event/free-festival', '/event/phoenix-the-hardest-outdoor-festival', '/event/daydream-festival-netherlands', '/event/pukkelpop', '/event/reverze', '/event/beat-the-bridge', '/event/matrixx-at-the-park', '/event/shockerz', '/event/dance-valley', '/event/psy-fi', '/event/hardfest', '/event/dockyard-festival-ade', '/event/ultrasonic-festival', '/event/extrema-outdoor-netherlands', '/event/neverland', '/event/laundry-day', '/event/dance-d-vision', '/event/drumcode-festival', '/event/city-of-dance-festival', '/event/paradise-city-festival', '/event/kingsland-festival-amsterdam', '/event/essential-festival', '/event/dance-4-liberation', '/event/straf-werk-festival', '/event/kingsland-festival-groningen', '/event/hard-bass', '/event/loudness', '/event/wildeburg', '/event/into-the-woods-festival', '/event/luminosity-beach-festival', '/event/ostend-beach-dance-festival', '/event/lowlands', '/event/soenda-festival', '/event/wecandance', '/event/kingsland-festival-twente', '/event/free-your-mind-festival', '/event/united', '/event/dance-boulevard', '/event/loveland-ade-hyte', '/event/we-are-hardstyle-indoor', '/event/groundzero-festival', '/event/daylight-festival', '/event/18hrs-festival', '/event/innovation-in-the-dam', '/event/royaal-kabaal', '/event/dont-let-daddy-know-amsterdam', '/event/promised-land-festival', '/event/festyland', '/event/castle-of-love', '/event/toffler-festival', '/event/rampage', '/event/karnaval-festival', '/event/korsakov-indoor-festival', '/event/pandemonium', '/event/cirque-magique-festival', '/event/verknipt-ade-special-day-2', '/event/the-flying-dutch-amsterdam', '/event/afterlife-ade', '/event/qlimax', '/event/music-on-festival-amsterdam', '/event/the-ace-of-spades', '/event/unity-indoor', '/event/the-flying-dutch-eindhoven', '/event/valhalla-festival', '/event/the-flying-dutch-rotterdam', '/event/wow-wow', '/event/supremacy', '/event/fuze-outdoor', '/event/loveland-van-oranje', '/event/beatcoin-festival']

# %% [markdown]
# FUNCTION FOR COLLECTING INFO

# %%
#This cell is the main function used to scrape the Top100.
#Most parts are structured very similar to one another but with different objectives.
#Several of the steps contain a print() command. This was left in to make sure the information is being collected, but can be commented out if not necessary.
#URL and CSVFILE must be in ""
def collect_info(url, csvfile):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    
    #NAME
    name = ''
    festival_name = soup.find_all('h1')
    for festival_name in festival_name:
        name = festival_name.text.strip()
    print(name)
    
    #COUNTRY
    country = ''
    festival_country = soup.find_all('div', {'class': 'country-name'})
    for festival_country in festival_country:
        country = festival_country.text.strip() 
    print(country)
    
    #GENRES
    #The Genres were presented in a rather weird way because they grouped several together as similar genres. Therefor the code splits the ' // '
    #That they used to seperate the Genres. Giving us a clearer list of Genres.
    genres = ''
    festival_genres = soup.find_all('div', {'class': 'genrelist'})
    for festival_genres in festival_genres:
        new_fgenres = festival_genres.text.strip()
        new_fgenres = new_fgenres.split(' // ')
        genres = new_fgenres
    print(genres)
    
    #LINEUP
    dates = soup.find_all('div', {'class': 'field-date'})
    data = []

    #The HTML for the website grouped the date of a festival with the artists resulting in a significant amount of complications.
    #This is also where most of the time coding was spent. Finally this section managed to seperate the date and the artists into a dictionary that took date as a key,
    #And the list of artists as the corresponding data.
    #Afterwards the data is divided across a series of lists based on the year the festival took place.
    for date in dates:
        item = {"date": "", "artists": []}
        for el in date.parent:
            if(el.name == "div"):
                item['date'] += el.get_text()

            elif(el.name == "a"):
                item['artists'].append(el.get_text())
        data.append(item)
    
    other_lineups = []
    lineup2017 = []
    lineup2018 = []
    lineup2019 = []

    for dic in data:
        if '2017' in dic['date']:
            lineup2017 = dic['artists']
        elif '2018' in dic['date']:
            lineup2018 = dic['artists']
        elif '2019' in dic['date']:
            lineup2019 = dic['artists']
        else:
            other_lineups += dic['artists']
        
    
    #WRITE TO CSV
    #The Data is then added to a csv file.
    #It is important to change the names of the fields in case they are changed earlier on.
    with open(csvfile, 'a', encoding= "utf-8") as csvfile:
        fieldnames = ['name', 'country', 'genres', 'lineup_2017', 'lineup_2018', 'lineup_2019', 'other_lineups']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writerow({'name': name, 'country': country, 'genres': genres, 'lineup_2017': lineup2017, 'lineup_2018': lineup2018, 'lineup_2019': lineup2019, 'other_lineups': other_lineups})
    
    return

# %% [markdown]
# SCRAPE

# %%
#This cell uses the function and information from the previous cells to scrape a top100 list on electronic-festivals.com.
#The resulting information will be stored in the CSV file you created earlier.
for add in addons:
    link = 'https://www.electronic-festivals.com' + add
    URL = link
    csvfile = 'Top100Benelux.csv'
    collect_info(URL, csvfile)
# Out:
# Amsterdam Dance Event
# Netherlands
# ['Electro', 'POP', 'Techno', 'Tech House', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass', 'Big Room', 'EDM', 'Trance', 'Drum & Bass', 'Chillout', 'Down Tempo', 'Hardcore', 'Hardstyle', 'Goa', 'Psytrance', 'Experimental']
# Tomorrowland
# Belgium
# ['Techno', 'Tech House', 'Big Room', 'EDM', 'Trance', 'House', 'Deep House', 'Drum & Bass', 'Dubstep', 'Trap', 'Bass', 'Hardcore', 'Hardstyle', 'Goa', 'Psytrance']
# Tomorrowland - Weekend 2
# Belgium
# ['Techno', 'Tech House', 'Big Room', 'EDM', 'Trance', 'House', 'Deep House', 'Drum & Bass', 'Dubstep', 'Trap', 'Bass', 'Hardcore', 'Hardstyle', 'Goa', 'Psytrance']
# Mysteryland
# Netherlands
# ['Big Room', 'EDM', 'Techno', 'Tech House', 'Hardcore', 'Hardstyle', 'Dubstep', 'Trap', 'Bass', 'House', 'Deep House', 'Chillout', 'Down Tempo', 'Drum & Bass', 'Trance']
# Defqon1
# Netherlands
# ['Hardcore', 'Hardstyle']
# Awakenings Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Intents Festival
# Netherlands
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM']
# Decibel Outdoor Festival
# Netherlands
# ['Hardcore', 'Hardstyle', 'Techno', 'Tech House']
# The Qontinent
# Belgium
# ['Hardcore', 'Hardstyle']
# Extrema Outdoor - Belgium
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House']
# Emporium Festival
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'Techno', 'Tech House', 'Trance', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass']
# Rebirth Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# Supersized Kingsday
# Netherlands
# ['Hardcore', 'Hardstyle']
# Amsterdam Open Air
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House', 'Big Room', 'EDM', 'Dubstep', 'Trap', 'Bass']
# DGTL Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Dominator - The Hardcore Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# Masters of Hardcore - NL
# Netherlands
# ['Hardcore', 'Hardstyle']
# Sunrise Festival - Belgium
# Belgium
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM', 'Techno', 'Tech House', 'Trance', 'House', 'Deep House', 'Drum & Bass']
# Loveland Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# We Are Electric
# Netherlands
# ['Techno', 'Tech House', 'Big Room', 'EDM', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass', 'Drum & Bass']
# Dream Village
# Netherlands
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM', 'House', 'Deep House']
# Freshtival
# Netherlands
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM', 'House', 'Deep House', 'Techno', 'Tech House']
# So W'happy
# Belgium
# ['Hardcore', 'Hardstyle', 'House', 'Deep House', 'Drum & Bass']
# 7th Sunday Festival
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'Techno', 'Tech House', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass']
# Airforce Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# WiSH Outdoor - netherlands
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House', 'Techno', 'Tech House']
# Dekmantel Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House', 'Chillout', 'Down Tempo', 'Electro', 'POP', 'Experimental']
# Welcome to the Future
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Dreamfields
# Netherlands
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM', 'House', 'Deep House']
# Dourfestival
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House', 'Electro', 'POP', 'Dubstep', 'Trap', 'Bass', 'Drum & Bass']
# Free Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# Phoenix - The Hardest Outdoor Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# Daydream Festival - Netherlands
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House', 'Techno', 'Tech House']
# Pukkelpop
# Belgium
# ['Drum & Bass', 'Techno', 'Tech House', 'Electro', 'POP', 'House', 'Deep House']
# Reverze
# Belgium
# ['Hardcore', 'Hardstyle']
# Beat the Bridge
# Netherlands
# ['Hardcore', 'Hardstyle']
# Matrixx at the Park
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House']
# Shockerz
# Netherlands
# ['Hardcore', 'Hardstyle']
# Dance Valley
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House', 'Trance', 'Techno', 'Tech House', 'Dubstep', 'Trap', 'Bass']
# Psy Fi
# Netherlands
# ['Goa', 'Psytrance', 'Chillout', 'Down Tempo', 'Techno', 'Tech House']
# Hardfest
# Netherlands
# ['Hardcore', 'Hardstyle']
# DockYard Festival - ADE
# Netherlands
# ['Techno', 'Tech House']
# Ultrasonic Festival
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'Techno', 'Tech House', 'Trance', 'House', 'Deep House']
# Extrema Outdoor - Netherlands
# Netherlands
# ['Big Room', 'EDM', 'House', 'Deep House', 'Techno', 'Tech House']
# Neverland
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House', 'Big Room', 'EDM', 'Hardcore', 'Hardstyle']
# Laundry Day
# Belgium
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House', 'Drum & Bass', 'Dubstep', 'Trap', 'Bass', 'Techno', 'Tech House']
# Dance D-Vision
# Belgium
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House', 'Techno', 'Tech House']
# Drumcode Festival
# Netherlands
# ['Techno', 'Tech House']
# City of Dance Festival
# Netherlands
# ['Big Room', 'EDM', 'House', 'Deep House', 'Hardcore', 'Hardstyle', 'Techno', 'Tech House']
# Paradise City Festival
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House']
# Kingsland Festival - Amsterdam
# Netherlands
# ['Big Room', 'EDM', 'Techno', 'Tech House', 'House', 'Deep House', 'Hardcore', 'Hardstyle']
# Essential Festival
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'House', 'Deep House']
# Dance 4 Liberation
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle']
# SWF
# Netherlands
# ['House', 'Deep House', 'Techno', 'Tech House']
# Kingsland Festival - Groningen
# Netherlands
# ['Big Room', 'EDM', 'House', 'Deep House']
# Hard Bass
# Netherlands
# ['Hardcore', 'Hardstyle']
# Loudness
# Netherlands
# ['Hardcore', 'Hardstyle']
# Wildeburg
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House', 'Chillout', 'Down Tempo']
# Into the Woods Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# LUMINOSITY BEACH FESTIVAL
# Netherlands
# ['Trance', 'Big Room', 'EDM']
# Ostend Beach Dance Festival
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House', 'Big Room', 'EDM', 'Goa', 'Psytrance']
# Lowlands
# Netherlands
# ['Drum & Bass', 'House', 'Deep House', 'Techno', 'Tech House', 'Electro', 'POP']
# Soenda Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# WECANDANCE
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House']
# Kingsland Festival - Twente
# Netherlands
# ['Hardcore', 'Hardstyle']
# Free Your Mind Festival
# Netherlands
# ['Techno', 'Tech House', 'Big Room', 'EDM', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass']
# United
# Belgium
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle']
# Dance Boulevard
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle', 'Techno', 'Tech House', 'House', 'Deep House', 'Dubstep', 'Trap', 'Bass']
# Loveland ADE - HYTE
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# We are Hardstyle - Indoor
# Netherlands
# ['Hardcore', 'Hardstyle']
# Groundzero Festival
# Netherlands
# ['Hardcore', 'Hardstyle', 'Techno', 'Tech House']
# Airborne festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# 18hrs Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Innovation in the Dam
# Netherlands
# ['Drum & Bass']
# Royaal Kabaal
# Netherlands
# ['Hardcore', 'Hardstyle']
# Dont let Daddy Know - Amsterdam
# Netherlands
# ['Big Room', 'EDM', 'Hardcore', 'Hardstyle']
# Promised Land Festival
# Netherlands
# ['Hardcore', 'Hardstyle', 'Big Room', 'EDM', 'Techno', 'Tech House', 'House', 'Deep House']
# Festyland
# Netherlands
# ['House', 'Deep House', 'Hardcore', 'Hardstyle', 'Electro', 'POP']
# Castle Of Love
# Netherlands
# ['Big Room', 'EDM', 'Electro', 'POP', 'Dubstep', 'Trap', 'Bass', 'Hardcore', 'Hardstyle', 'House', 'Deep House']
# Toffler Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Rampage
# Belgium
# ['Dubstep', 'Trap', 'Bass', 'Drum & Bass']
# Karnaval Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
# Korsakov - Indoor Festival
# Netherlands
# ['Drum & Bass']
# Pandemonium
# Netherlands
# ['Hardcore', 'Hardstyle']
# Cirque Magique Festival
# Belgium
# ['Techno', 'Tech House', 'House', 'Deep House']
# Verknipt ADE special - Day 2
# Netherlands
# ['House', 'Deep House', 'Techno', 'Tech House']
# The Flying Dutch - Amsterdam
# Netherlands
# ['Trance', 'Big Room', 'EDM', 'House', 'Deep House']
# Afterlife - ADE
# Netherlands
# ['Techno', 'Tech House']
# QLIMAX
# Netherlands
# ['Hardcore', 'Hardstyle']
# Music On Festival - Amsterdam
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# The Ace Of Spades
# Netherlands
# ['Hardcore', 'Hardstyle']
# UNITY - INDOOR
# Netherlands
# ['Hardcore', 'Hardstyle']
# The Flying Dutch - Eindhoven
# Netherlands
# ['Trance', 'Big Room', 'EDM', 'House', 'Deep House']
# Valhalla Festival
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House', 'Big Room', 'EDM']
# The Flying Dutch - Rotterdam
# Netherlands
# ['Trance', 'Big Room', 'EDM', 'House', 'Deep House']
# WOW WOW
# Netherlands
# ['Hardcore', 'Hardstyle']
# Supremacy
# Netherlands
# ['Hardcore', 'Hardstyle']
# Fuze Outdoor
# Netherlands
# ['Hardcore', 'Hardstyle', 'Electro', 'POP', 'Big Room', 'EDM']
# Loveland Van Oranje
# Netherlands
# ['Techno', 'Tech House', 'House', 'Deep House']
# Beatcoin Festival
# Netherlands
# ['Hardcore', 'Hardstyle']
